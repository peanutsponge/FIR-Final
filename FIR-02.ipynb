# %% [markdown]
# ## Assignment 2 - _Foundations of Information Retrieval 2023_
#
# The second assignment is divided in two parts and it is due on October 29th at 23:59, via Canvas (no deadline extentions).
# The first part is about _learning-to-rank_ exercises and the use of a regression and SVM for ranking. You will work on a data set of document, for which two features are extracted. The second part contains small practical image retrieval exercises using the Bag-of-Words framework, using images of the city of London.
#
# ### Background information
# Please study the materials provided with Lecture 4 (for Part 01) and Lecture 6 (for Part 02) to have a solid theoretical base to solve the following exercises.
#
# To simplify many operations, you can use Python libraries for Machine Learning (for Part 01 and Part 02) and Image Processing (only for Part 02). We advise you to familiarize with:
# * [scikit-learn](): library for Machine Learning
# * [scikit-image](): library of functions for image processing
# * [matplotlib](): for visualizations and plots

# %% [markdown]
# ### Install needed libraries and tools
# The required libraries are already installed in the virtual machine system.
# If you run the notebook on your machine, you can install the libraries by running the cell below.

# %%
# Scikit-image library for image processing tools in python
# !pip3 install scikit-image
# Scikit-learn library for ML in python
# !pip3 install scikit-learn
# install the library h5py (needed to load and read the ground truth relevance file of assignment 02)
# !pip3 install h5py
# install the library tqdm (for progress visualization)
# !pip3 install tqdm
# Matplotlib/Pylab for plots and visualization in python
# !pip3 install matplotlib
# Out:
# Requirement already satisfied: scikit-image in c:\users\damia\miniconda3\lib\site-packages (0.22.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\damia\miniconda3\lib\site-packages (from scikit-image) (2.31.6)
# Requirement already satisfied: scipy>=1.8 in c:\users\damia\miniconda3\lib\site-packages (from scikit-image) (1.11.3)
# Requirement already satisfied: networkx>=2.8 in c:\users\damia\miniconda3\lib\site-packages (from scikit-image) (3.2)
# Requirement already satisfied: lazy_loader>=0.3 in c:\users\damia\miniconda3\lib\site-packages (from scikit-image) (0.3)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\damia\miniconda3\lib\site-packages (from scikit-image) (2023.9.26)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\damia\miniconda3\lib\site-packages (from scikit-image) (10.0.1)
# Requirement already satisfied: numpy>=1.22 in c:\users\damia\miniconda3\lib\site-packages (from scikit-image) (1.26.1)
# Requirement already satisfied: packaging>=21 in c:\users\damia\miniconda3\lib\site-packages (from scikit-image) (23.1)
# Requirement already satisfied: scikit-learn in c:\users\damia\miniconda3\lib\site-packages (1.3.1)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\damia\miniconda3\lib\site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\damia\miniconda3\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\damia\miniconda3\lib\site-packages (from scikit-learn) (1.26.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\damia\miniconda3\lib\site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: h5py in c:\users\damia\miniconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\damia\miniconda3\lib\site-packages (from h5py) (1.26.1)
# Requirement already satisfied: tqdm in c:\users\damia\miniconda3\lib\site-packages (4.64.1)
# Requirement already satisfied: colorama in c:\users\damia\miniconda3\lib\site-packages (from tqdm) (0.4.5)
# Requirement already satisfied: matplotlib in c:\users\damia\miniconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\damia\miniconda3\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\damia\miniconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\damia\miniconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\damia\miniconda3\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\damia\miniconda3\lib\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\damia\miniconda3\lib\site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\damia\miniconda3\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\damia\miniconda3\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\damia\miniconda3\lib\site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\damia\miniconda3\lib\site-packages (from matplotlib) (6.1.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\damia\miniconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\damia\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# # Part 02: Image Retrieval

# %% [markdown]
# _You are suggested to work on this part after Lecture 06 (Multimedia Information Retrieval - Image Retrieval)_
#
# In the second part of the assignment, you will work on a simple image retrieval problem, and implement parts of the Bag Of Words retrieval approach. You will work with images from the Mapillary Street-Level Sequences  (MSLS) data set. For an autonomous car, for instance, it is important to retrieve from a map or reference set of images the most similar images to what is being recording with a camera, in order to recognize a previously visited place.
#
# You are asked to retrieve, from a collection of city images (we work with images from London), the most similar images to given queries. For this, we provide you a dataset, composed of:
#
# * _database/_ folder: contains XXX images used as map (document collection)
# * _query/_ folder: contains XXX images used as queries
# * _database/database_lite.json_: list of images included in the map (the order is important because it correspond to the orded in the similarity matrix - see below)
# * _query/query_lite.json_: list of images used for query (the order is important because it correspond to the orded in the similarity matrix - see below)
# * _london_lite_gt.h5_: matrix of image similarity, containts all the information about relevant/non-relevant images
#
# __Relevance judgements (in the form of a matrix, the structure of which is explained below)__
# For each query image, we provide a specification of which map images are relevant (1 in the london_lite_gt.h5 file) and which are not (0 in the london_lite_gt.h5). The content of the '.h5' file is a matrix, with rows corresponding to query images and columns corresponding to the map images. The matrix has thus has $N=500$ rows (where $N$ is the number of query images in the folder `query/images/`) and $M=1000$ columns (where $M$ is the number of query images in the folder `database/images/`).
#
# The $i$-th row of the matrix thus contains the relevance judgement for the $i$-th query image with respect to the map images. For instance, row 5 of the matrix is a vector of 1000 elements (one for each image in the map), in which each element is 1 if the corresponding map image is relevant for the query image 5, or $0$ in case it is not relevant.
#
# Please note that in Python the index of a vector (or matrix) starts from 0 (instead of 1). This means that the first element of a vector has index $0$, and that, for example, the element with index $25$ corresponds to the 26-th element of the vector.
# Thus, as an example, the cell $(10, 25)$ contains the relevance of the 26-th map image for the $11$-th query image (i.e. is the 26-th image in the map relevan (1) or not (0) for the query image number 11?).
#
#
# In the following, we provide you the code for loading the data set and to visualize the images.
#
#
# > Note: for this assignment we use the '\_lite' version of the map and query set, which include a reduced number of images. This is to simplify the computations required to work on this assignment. For the final project, you can work using the full-sized sets of images from London. This will require longer computations, but you can obtain more reliable results.

# %% [markdown]
# ## Load the query and map images
# In the following we load the list of images in the map set (collection) and in the query set.
# For each image, we have information also about the absolute coordinates of the camera that took the picture in the city of London. _Do not consider these coordinates for the exercises. We use them only to show the trajectory followed by the camera taking the pictures (see below)._

# %%
import json
import numpy as np
import h5py
import matplotlib.pyplot as plt
import tqdm

# map
with open("data02/database/database_lite.json","r") as f:
    m_idx = json.load(f)
    m_imgs = np.array(m_idx["im_paths"])
    m_loc=np.array(m_idx["loc"])

# query
with open("data02/query/query_lite.json","r") as f:
    q_idx=json.load(f)
    q_imgs=np.array(q_idx["im_paths"])
    q_loc=np.array(q_idx["loc"])

# %% [markdown]
# ### Visualization of image locations
# The pictures in the map (collection) and query sets have been recorded in different parts of the city of London. The map images are indicated by the blue trajectory (run the code below), while the query images are indicated by the orange trajectory segments.
#
# You can notice how the blue and orange trajectories overlap partially. In that overlapping area, the query images will have some relevant images among the map images. Conversely, in the areas there there is no overlap (and the points are not even close), the map images will be non-relevant for the query images.
# Please read more details in the next sections, where the ground truth relevance judgements are provided and explained.

# %%
plt.scatter(m_loc[:,0],m_loc[:,1], label="Map")
plt.scatter(q_loc[:,0],q_loc[:,1], label="Query", s=0.5)
#plt.axis("equal")
plt.xticks([])
plt.yticks([])
plt.legend()
plt.show()

# %% [markdown]
# ## Load the similarity matrix (relevance judgements)
#
# The london_lite_gt.h5 file contains two sets of relevance  judgements, specified by the keys `sim` and `fov`.
# `sim` specifies it in the form 0/1 (non-relevant/relevant).
# `fov` (that stands for field of view) specifies it as a degree of similarity, a value defined in the interval $[0, 1]$ that indicates how much the query and map images are similar. We do not use it for this assignment, but you may consider it when working on the final project.

# %%
# loading the relevance judgements
with h5py.File("data02/london_lite_gt.h5","r") as f:
    fovs = f["fov"][:]
    sim = f["sim"][:].astype(np.uint8)

# %% [markdown]
# We use the matrix with binary relevance judgements `sim` in this assignment.
# To obtain the relevance judgement of the map image 'map_id' for the query 'query_id', you  can use the syntax `sim[query_id, map_id]`.
#
# In the following we show few examples:

# %%
# note that for the 10th map image we have to access column 10-1=9
print('Relevance of the 10th map image for the 5th query image: ', sim[4, 9])
# similarly for the 221th query image we access column 221-1=220
print('Relevance of the 221th map image for the 151th query image: ', sim[150, 220])
# Out:
# Relevance of the 10th map image for the 5th query image:  0
# Relevance of the 221th map image for the 151th query image:  1

# %% [markdown]
# ### Distribution of relevant images per query
#
# The majority of query images have between $0$ and $10$ relevant map images (ground truth positive matches). A few query images have no relevant map images (no positive matches) in the database. A few others have up to $30$ positive database images.

# %%
plt.hist(np.sum(sim, axis=1),bins=50)
plt.xlabel('Image count')
plt.ylabel('Relevant map images')
plt.title('Distribution of relevant images')
plt.show()

# %% [markdown]
# ### Visualization of random images.
# For a given query image, we select one relevant and one non-relevant image from the map.
# > By running several time the following cell, you can see how some of the relevant images are very difficult cases. This can give an idea of how complicate is to perform robust image retrieval.
# This is also an indication that the retrieval results that you will compute will not be high (do not worry about them, then - focus on the methodology and discussions).
#
# See below:

# %%
# generate random index for the query image
# You can try with it (but in the case a query image does not have relevant results in the map, the code will give an error)
query_idx = np.random.randint(0, 499) 

# For visualization purposes, we select a query image for which there are relevant and non-relevant results in the collection (map)
# query_idx = 120

# select the relevant and non-relevant map images for the randomly selected query image
rel = np.where(sim[query_idx, :] == 1)
nonrel = np.where(sim[query_idx, :] == 0)


# randomly select a relevant and non-relevant image
rel_idx = rel[0][np.random.randint(0, len(rel[0]) - 1)]
nonrel_idx = nonrel[0][np.random.randint(0, len(nonrel[0]) - 1)]

plt.figure(figsize=(17,10))
plt.subplot(1,3,1)
plt.imshow(plt.imread('data02/' + q_imgs[query_idx]))
plt.axis("off")

plt.subplot(1,3,2)
plt.title('Relevant image result (from map)')
plt.imshow(plt.imread('data02/' + m_imgs[rel_idx]))
plt.axis("off")

plt.subplot(1,3,3)
plt.title('Non-relevant image result (from map)')
plt.imshow(plt.imread('data02/' + m_imgs[nonrel_idx]))
plt.axis("off")
# Out:
# (-0.5, 340.5, 255.5, -0.5)

# %% [markdown]
# If you want to collect all relevance judgement for the $i$-th query image, you need to access the (i-1)-th row of the matrix `sim`. To visualize the relevance judgment you have to loop over the accesses vector (a row of a matrix is a vector.
#
# In the following an example of how to do that.

# %%
# accessing (and printing out) the relevance judgement for the query image number 16

query_id = 15  # 16-1
for idx in range(len(sim[query_id, :])):
    # idx is the index of the vector. It corresponds to the map image index
    # rel contains the relevance (0/1) of the idx-th map image for the considered query image (9th image in our case)
    print("Relevance of the %d-th map image for the 16-th query image: %d" % (idx, sim[query_id, idx]))
# Out:
# Relevance of the 0-th map image for the 16-th query image: 0
# Relevance of the 1-th map image for the 16-th query image: 0
# Relevance of the 2-th map image for the 16-th query image: 0
# Relevance of the 3-th map image for the 16-th query image: 0
# Relevance of the 4-th map image for the 16-th query image: 0
# Relevance of the 5-th map image for the 16-th query image: 0
# Relevance of the 6-th map image for the 16-th query image: 1
# Relevance of the 7-th map image for the 16-th query image: 1
# Relevance of the 8-th map image for the 16-th query image: 1
# Relevance of the 9-th map image for the 16-th query image: 1
# Relevance of the 10-th map image for the 16-th query image: 1
# Relevance of the 11-th map image for the 16-th query image: 1
# Relevance of the 12-th map image for the 16-th query image: 1
# Relevance of the 13-th map image for the 16-th query image: 1
# Relevance of the 14-th map image for the 16-th query image: 1
# Relevance of the 15-th map image for the 16-th query image: 1
# Relevance of the 16-th map image for the 16-th query image: 1
# Relevance of the 17-th map image for the 16-th query image: 1
# Relevance of the 18-th map image for the 16-th query image: 1
# Relevance of the 19-th map image for the 16-th query image: 1
# Relevance of the 20-th map image for the 16-th query image: 1
# Relevance of the 21-th map image for the 16-th query image: 1
# Relevance of the 22-th map image for the 16-th query image: 0
# Relevance of the 23-th map image for the 16-th query image: 0
# Relevance of the 24-th map image for the 16-th query image: 0
# Relevance of the 25-th map image for the 16-th query image: 0
# Relevance of the 26-th map image for the 16-th query image: 0
# Relevance of the 27-th map image for the 16-th query image: 0
# Relevance of the 28-th map image for the 16-th query image: 0
# Relevance of the 29-th map image for the 16-th query image: 0
# Relevance of the 30-th map image for the 16-th query image: 0
# Relevance of the 31-th map image for the 16-th query image: 0
# Relevance of the 32-th map image for the 16-th query image: 0
# Relevance of the 33-th map image for the 16-th query image: 0
# Relevance of the 34-th map image for the 16-th query image: 0
# Relevance of the 35-th map image for the 16-th query image: 0
# Relevance of the 36-th map image for the 16-th query image: 0
# Relevance of the 37-th map image for the 16-th query image: 0
# Relevance of the 38-th map image for the 16-th query image: 0
# Relevance of the 39-th map image for the 16-th query image: 0
# Relevance of the 40-th map image for the 16-th query image: 0
# Relevance of the 41-th map image for the 16-th query image: 0
# Relevance of the 42-th map image for the 16-th query image: 0
# Relevance of the 43-th map image for the 16-th query image: 0
# Relevance of the 44-th map image for the 16-th query image: 0
# Relevance of the 45-th map image for the 16-th query image: 0
# Relevance of the 46-th map image for the 16-th query image: 0
# Relevance of the 47-th map image for the 16-th query image: 0
# Relevance of the 48-th map image for the 16-th query image: 0
# Relevance of the 49-th map image for the 16-th query image: 0
# Relevance of the 50-th map image for the 16-th query image: 0
# Relevance of the 51-th map image for the 16-th query image: 0
# Relevance of the 52-th map image for the 16-th query image: 0
# Relevance of the 53-th map image for the 16-th query image: 0
# Relevance of the 54-th map image for the 16-th query image: 0
# Relevance of the 55-th map image for the 16-th query image: 0
# Relevance of the 56-th map image for the 16-th query image: 0
# Relevance of the 57-th map image for the 16-th query image: 0
# Relevance of the 58-th map image for the 16-th query image: 0
# Relevance of the 59-th map image for the 16-th query image: 0
# Relevance of the 60-th map image for the 16-th query image: 0
# Relevance of the 61-th map image for the 16-th query image: 0
# Relevance of the 62-th map image for the 16-th query image: 0
# Relevance of the 63-th map image for the 16-th query image: 0
# Relevance of the 64-th map image for the 16-th query image: 0
# Relevance of the 65-th map image for the 16-th query image: 0
# Relevance of the 66-th map image for the 16-th query image: 0
# Relevance of the 67-th map image for the 16-th query image: 0
# Relevance of the 68-th map image for the 16-th query image: 0
# Relevance of the 69-th map image for the 16-th query image: 0
# Relevance of the 70-th map image for the 16-th query image: 0
# Relevance of the 71-th map image for the 16-th query image: 0
# Relevance of the 72-th map image for the 16-th query image: 0
# Relevance of the 73-th map image for the 16-th query image: 0
# Relevance of the 74-th map image for the 16-th query image: 0
# Relevance of the 75-th map image for the 16-th query image: 0
# Relevance of the 76-th map image for the 16-th query image: 0
# Relevance of the 77-th map image for the 16-th query image: 0
# Relevance of the 78-th map image for the 16-th query image: 0
# Relevance of the 79-th map image for the 16-th query image: 0
# Relevance of the 80-th map image for the 16-th query image: 0
# Relevance of the 81-th map image for the 16-th query image: 0
# Relevance of the 82-th map image for the 16-th query image: 0
# Relevance of the 83-th map image for the 16-th query image: 0
# Relevance of the 84-th map image for the 16-th query image: 0
# Relevance of the 85-th map image for the 16-th query image: 0
# Relevance of the 86-th map image for the 16-th query image: 0
# Relevance of the 87-th map image for the 16-th query image: 0
# Relevance of the 88-th map image for the 16-th query image: 0
# Relevance of the 89-th map image for the 16-th query image: 0
# Relevance of the 90-th map image for the 16-th query image: 0
# Relevance of the 91-th map image for the 16-th query image: 0
# Relevance of the 92-th map image for the 16-th query image: 0
# Relevance of the 93-th map image for the 16-th query image: 0
# Relevance of the 94-th map image for the 16-th query image: 0
# Relevance of the 95-th map image for the 16-th query image: 0
# Relevance of the 96-th map image for the 16-th query image: 0
# Relevance of the 97-th map image for the 16-th query image: 0
# Relevance of the 98-th map image for the 16-th query image: 0
# Relevance of the 99-th map image for the 16-th query image: 0
# Relevance of the 100-th map image for the 16-th query image: 0
# Relevance of the 101-th map image for the 16-th query image: 0
# Relevance of the 102-th map image for the 16-th query image: 0
# Relevance of the 103-th map image for the 16-th query image: 0
# Relevance of the 104-th map image for the 16-th query image: 0
# Relevance of the 105-th map image for the 16-th query image: 0
# Relevance of the 106-th map image for the 16-th query image: 0
# Relevance of the 107-th map image for the 16-th query image: 0
# Relevance of the 108-th map image for the 16-th query image: 0
# Relevance of the 109-th map image for the 16-th query image: 0
# Relevance of the 110-th map image for the 16-th query image: 0
# Relevance of the 111-th map image for the 16-th query image: 0
# Relevance of the 112-th map image for the 16-th query image: 0
# Relevance of the 113-th map image for the 16-th query image: 0
# Relevance of the 114-th map image for the 16-th query image: 0
# Relevance of the 115-th map image for the 16-th query image: 0
# Relevance of the 116-th map image for the 16-th query image: 0
# Relevance of the 117-th map image for the 16-th query image: 0
# Relevance of the 118-th map image for the 16-th query image: 0
# Relevance of the 119-th map image for the 16-th query image: 0
# Relevance of the 120-th map image for the 16-th query image: 0
# Relevance of the 121-th map image for the 16-th query image: 0
# Relevance of the 122-th map image for the 16-th query image: 0
# Relevance of the 123-th map image for the 16-th query image: 0
# Relevance of the 124-th map image for the 16-th query image: 0
# Relevance of the 125-th map image for the 16-th query image: 0
# Relevance of the 126-th map image for the 16-th query image: 0
# Relevance of the 127-th map image for the 16-th query image: 0
# Relevance of the 128-th map image for the 16-th query image: 0
# Relevance of the 129-th map image for the 16-th query image: 0
# Relevance of the 130-th map image for the 16-th query image: 0
# Relevance of the 131-th map image for the 16-th query image: 0
# Relevance of the 132-th map image for the 16-th query image: 0
# Relevance of the 133-th map image for the 16-th query image: 0
# Relevance of the 134-th map image for the 16-th query image: 0
# Relevance of the 135-th map image for the 16-th query image: 0
# Relevance of the 136-th map image for the 16-th query image: 0
# Relevance of the 137-th map image for the 16-th query image: 0
# Relevance of the 138-th map image for the 16-th query image: 0
# Relevance of the 139-th map image for the 16-th query image: 0
# Relevance of the 140-th map image for the 16-th query image: 0
# Relevance of the 141-th map image for the 16-th query image: 0
# Relevance of the 142-th map image for the 16-th query image: 0
# Relevance of the 143-th map image for the 16-th query image: 0
# Relevance of the 144-th map image for the 16-th query image: 0
# Relevance of the 145-th map image for the 16-th query image: 0
# Relevance of the 146-th map image for the 16-th query image: 0
# Relevance of the 147-th map image for the 16-th query image: 0
# Relevance of the 148-th map image for the 16-th query image: 0
# Relevance of the 149-th map image for the 16-th query image: 0
# Relevance of the 150-th map image for the 16-th query image: 0
# Relevance of the 151-th map image for the 16-th query image: 0
# Relevance of the 152-th map image for the 16-th query image: 0
# Relevance of the 153-th map image for the 16-th query image: 0
# Relevance of the 154-th map image for the 16-th query image: 0
# Relevance of the 155-th map image for the 16-th query image: 0
# Relevance of the 156-th map image for the 16-th query image: 0
# Relevance of the 157-th map image for the 16-th query image: 0
# Relevance of the 158-th map image for the 16-th query image: 0
# Relevance of the 159-th map image for the 16-th query image: 0
# Relevance of the 160-th map image for the 16-th query image: 0
# Relevance of the 161-th map image for the 16-th query image: 0
# Relevance of the 162-th map image for the 16-th query image: 0
# Relevance of the 163-th map image for the 16-th query image: 0
# Relevance of the 164-th map image for the 16-th query image: 0
# Relevance of the 165-th map image for the 16-th query image: 0
# Relevance of the 166-th map image for the 16-th query image: 0
# Relevance of the 167-th map image for the 16-th query image: 0
# Relevance of the 168-th map image for the 16-th query image: 0
# Relevance of the 169-th map image for the 16-th query image: 0
# Relevance of the 170-th map image for the 16-th query image: 0
# Relevance of the 171-th map image for the 16-th query image: 0
# Relevance of the 172-th map image for the 16-th query image: 0
# Relevance of the 173-th map image for the 16-th query image: 0
# Relevance of the 174-th map image for the 16-th query image: 0
# Relevance of the 175-th map image for the 16-th query image: 0
# Relevance of the 176-th map image for the 16-th query image: 0
# Relevance of the 177-th map image for the 16-th query image: 0
# Relevance of the 178-th map image for the 16-th query image: 0
# Relevance of the 179-th map image for the 16-th query image: 0
# Relevance of the 180-th map image for the 16-th query image: 0
# Relevance of the 181-th map image for the 16-th query image: 0
# Relevance of the 182-th map image for the 16-th query image: 0
# Relevance of the 183-th map image for the 16-th query image: 0
# Relevance of the 184-th map image for the 16-th query image: 0
# Relevance of the 185-th map image for the 16-th query image: 0
# Relevance of the 186-th map image for the 16-th query image: 0
# Relevance of the 187-th map image for the 16-th query image: 0
# Relevance of the 188-th map image for the 16-th query image: 0
# Relevance of the 189-th map image for the 16-th query image: 0
# Relevance of the 190-th map image for the 16-th query image: 0
# Relevance of the 191-th map image for the 16-th query image: 0
# Relevance of the 192-th map image for the 16-th query image: 0
# Relevance of the 193-th map image for the 16-th query image: 0
# Relevance of the 194-th map image for the 16-th query image: 0
# Relevance of the 195-th map image for the 16-th query image: 0
# Relevance of the 196-th map image for the 16-th query image: 0
# Relevance of the 197-th map image for the 16-th query image: 0
# Relevance of the 198-th map image for the 16-th query image: 0
# Relevance of the 199-th map image for the 16-th query image: 0
# Relevance of the 200-th map image for the 16-th query image: 0
# Relevance of the 201-th map image for the 16-th query image: 0
# Relevance of the 202-th map image for the 16-th query image: 0
# Relevance of the 203-th map image for the 16-th query image: 0
# Relevance of the 204-th map image for the 16-th query image: 0
# Relevance of the 205-th map image for the 16-th query image: 0
# Relevance of the 206-th map image for the 16-th query image: 0
# Relevance of the 207-th map image for the 16-th query image: 0
# Relevance of the 208-th map image for the 16-th query image: 0
# Relevance of the 209-th map image for the 16-th query image: 0
# Relevance of the 210-th map image for the 16-th query image: 0
# Relevance of the 211-th map image for the 16-th query image: 0
# Relevance of the 212-th map image for the 16-th query image: 0
# Relevance of the 213-th map image for the 16-th query image: 0
# Relevance of the 214-th map image for the 16-th query image: 0
# Relevance of the 215-th map image for the 16-th query image: 0
# Relevance of the 216-th map image for the 16-th query image: 0
# Relevance of the 217-th map image for the 16-th query image: 0
# Relevance of the 218-th map image for the 16-th query image: 0
# Relevance of the 219-th map image for the 16-th query image: 0
# Relevance of the 220-th map image for the 16-th query image: 0
# Relevance of the 221-th map image for the 16-th query image: 0
# Relevance of the 222-th map image for the 16-th query image: 0
# Relevance of the 223-th map image for the 16-th query image: 0
# Relevance of the 224-th map image for the 16-th query image: 0
# Relevance of the 225-th map image for the 16-th query image: 0
# Relevance of the 226-th map image for the 16-th query image: 0
# Relevance of the 227-th map image for the 16-th query image: 0
# Relevance of the 228-th map image for the 16-th query image: 0
# Relevance of the 229-th map image for the 16-th query image: 0
# Relevance of the 230-th map image for the 16-th query image: 0
# Relevance of the 231-th map image for the 16-th query image: 0
# Relevance of the 232-th map image for the 16-th query image: 0
# Relevance of the 233-th map image for the 16-th query image: 0
# Relevance of the 234-th map image for the 16-th query image: 0
# Relevance of the 235-th map image for the 16-th query image: 0
# Relevance of the 236-th map image for the 16-th query image: 0
# Relevance of the 237-th map image for the 16-th query image: 0
# Relevance of the 238-th map image for the 16-th query image: 0
# Relevance of the 239-th map image for the 16-th query image: 0
# Relevance of the 240-th map image for the 16-th query image: 0
# Relevance of the 241-th map image for the 16-th query image: 0
# Relevance of the 242-th map image for the 16-th query image: 0
# Relevance of the 243-th map image for the 16-th query image: 0
# Relevance of the 244-th map image for the 16-th query image: 0
# Relevance of the 245-th map image for the 16-th query image: 0
# Relevance of the 246-th map image for the 16-th query image: 0
# Relevance of the 247-th map image for the 16-th query image: 0
# Relevance of the 248-th map image for the 16-th query image: 0
# Relevance of the 249-th map image for the 16-th query image: 0
# Relevance of the 250-th map image for the 16-th query image: 0
# Relevance of the 251-th map image for the 16-th query image: 0
# Relevance of the 252-th map image for the 16-th query image: 0
# Relevance of the 253-th map image for the 16-th query image: 0
# Relevance of the 254-th map image for the 16-th query image: 0
# Relevance of the 255-th map image for the 16-th query image: 0
# Relevance of the 256-th map image for the 16-th query image: 0
# Relevance of the 257-th map image for the 16-th query image: 0
# Relevance of the 258-th map image for the 16-th query image: 0
# Relevance of the 259-th map image for the 16-th query image: 0
# Relevance of the 260-th map image for the 16-th query image: 0
# Relevance of the 261-th map image for the 16-th query image: 0
# Relevance of the 262-th map image for the 16-th query image: 0
# Relevance of the 263-th map image for the 16-th query image: 0
# Relevance of the 264-th map image for the 16-th query image: 0
# Relevance of the 265-th map image for the 16-th query image: 0
# Relevance of the 266-th map image for the 16-th query image: 0
# Relevance of the 267-th map image for the 16-th query image: 0
# Relevance of the 268-th map image for the 16-th query image: 0
# Relevance of the 269-th map image for the 16-th query image: 0
# Relevance of the 270-th map image for the 16-th query image: 0
# Relevance of the 271-th map image for the 16-th query image: 0
# Relevance of the 272-th map image for the 16-th query image: 0
# Relevance of the 273-th map image for the 16-th query image: 0
# Relevance of the 274-th map image for the 16-th query image: 0
# Relevance of the 275-th map image for the 16-th query image: 0
# Relevance of the 276-th map image for the 16-th query image: 0
# Relevance of the 277-th map image for the 16-th query image: 0
# Relevance of the 278-th map image for the 16-th query image: 0
# Relevance of the 279-th map image for the 16-th query image: 0
# Relevance of the 280-th map image for the 16-th query image: 0
# Relevance of the 281-th map image for the 16-th query image: 0
# Relevance of the 282-th map image for the 16-th query image: 0
# Relevance of the 283-th map image for the 16-th query image: 0
# Relevance of the 284-th map image for the 16-th query image: 0
# Relevance of the 285-th map image for the 16-th query image: 0
# Relevance of the 286-th map image for the 16-th query image: 0
# Relevance of the 287-th map image for the 16-th query image: 0
# Relevance of the 288-th map image for the 16-th query image: 0
# Relevance of the 289-th map image for the 16-th query image: 0
# Relevance of the 290-th map image for the 16-th query image: 0
# Relevance of the 291-th map image for the 16-th query image: 0
# Relevance of the 292-th map image for the 16-th query image: 0
# Relevance of the 293-th map image for the 16-th query image: 0
# Relevance of the 294-th map image for the 16-th query image: 0
# Relevance of the 295-th map image for the 16-th query image: 0
# Relevance of the 296-th map image for the 16-th query image: 0
# Relevance of the 297-th map image for the 16-th query image: 0
# Relevance of the 298-th map image for the 16-th query image: 0
# Relevance of the 299-th map image for the 16-th query image: 0
# Relevance of the 300-th map image for the 16-th query image: 0
# Relevance of the 301-th map image for the 16-th query image: 0
# Relevance of the 302-th map image for the 16-th query image: 0
# Relevance of the 303-th map image for the 16-th query image: 0
# Relevance of the 304-th map image for the 16-th query image: 0
# Relevance of the 305-th map image for the 16-th query image: 0
# Relevance of the 306-th map image for the 16-th query image: 0
# Relevance of the 307-th map image for the 16-th query image: 0
# Relevance of the 308-th map image for the 16-th query image: 0
# Relevance of the 309-th map image for the 16-th query image: 0
# Relevance of the 310-th map image for the 16-th query image: 0
# Relevance of the 311-th map image for the 16-th query image: 0
# Relevance of the 312-th map image for the 16-th query image: 0
# Relevance of the 313-th map image for the 16-th query image: 0
# Relevance of the 314-th map image for the 16-th query image: 0
# Relevance of the 315-th map image for the 16-th query image: 0
# Relevance of the 316-th map image for the 16-th query image: 0
# Relevance of the 317-th map image for the 16-th query image: 0
# Relevance of the 318-th map image for the 16-th query image: 0
# Relevance of the 319-th map image for the 16-th query image: 0
# Relevance of the 320-th map image for the 16-th query image: 0
# Relevance of the 321-th map image for the 16-th query image: 0
# Relevance of the 322-th map image for the 16-th query image: 0
# Relevance of the 323-th map image for the 16-th query image: 0
# Relevance of the 324-th map image for the 16-th query image: 0
# Relevance of the 325-th map image for the 16-th query image: 0
# Relevance of the 326-th map image for the 16-th query image: 0
# Relevance of the 327-th map image for the 16-th query image: 0
# Relevance of the 328-th map image for the 16-th query image: 0
# Relevance of the 329-th map image for the 16-th query image: 0
# Relevance of the 330-th map image for the 16-th query image: 0
# Relevance of the 331-th map image for the 16-th query image: 0
# Relevance of the 332-th map image for the 16-th query image: 0
# Relevance of the 333-th map image for the 16-th query image: 0
# Relevance of the 334-th map image for the 16-th query image: 0
# Relevance of the 335-th map image for the 16-th query image: 0
# Relevance of the 336-th map image for the 16-th query image: 0
# Relevance of the 337-th map image for the 16-th query image: 0
# Relevance of the 338-th map image for the 16-th query image: 0
# Relevance of the 339-th map image for the 16-th query image: 0
# Relevance of the 340-th map image for the 16-th query image: 0
# Relevance of the 341-th map image for the 16-th query image: 0
# Relevance of the 342-th map image for the 16-th query image: 0
# Relevance of the 343-th map image for the 16-th query image: 0
# Relevance of the 344-th map image for the 16-th query image: 0
# Relevance of the 345-th map image for the 16-th query image: 0
# Relevance of the 346-th map image for the 16-th query image: 0
# Relevance of the 347-th map image for the 16-th query image: 0
# Relevance of the 348-th map image for the 16-th query image: 0
# Relevance of the 349-th map image for the 16-th query image: 0
# Relevance of the 350-th map image for the 16-th query image: 0
# Relevance of the 351-th map image for the 16-th query image: 0
# Relevance of the 352-th map image for the 16-th query image: 0
# Relevance of the 353-th map image for the 16-th query image: 0
# Relevance of the 354-th map image for the 16-th query image: 0
# Relevance of the 355-th map image for the 16-th query image: 0
# Relevance of the 356-th map image for the 16-th query image: 0
# Relevance of the 357-th map image for the 16-th query image: 0
# Relevance of the 358-th map image for the 16-th query image: 0
# Relevance of the 359-th map image for the 16-th query image: 0
# Relevance of the 360-th map image for the 16-th query image: 0
# Relevance of the 361-th map image for the 16-th query image: 0
# Relevance of the 362-th map image for the 16-th query image: 0
# Relevance of the 363-th map image for the 16-th query image: 0
# Relevance of the 364-th map image for the 16-th query image: 0
# Relevance of the 365-th map image for the 16-th query image: 0
# Relevance of the 366-th map image for the 16-th query image: 0
# Relevance of the 367-th map image for the 16-th query image: 0
# Relevance of the 368-th map image for the 16-th query image: 0
# Relevance of the 369-th map image for the 16-th query image: 0
# Relevance of the 370-th map image for the 16-th query image: 0
# Relevance of the 371-th map image for the 16-th query image: 0
# Relevance of the 372-th map image for the 16-th query image: 0
# Relevance of the 373-th map image for the 16-th query image: 0
# Relevance of the 374-th map image for the 16-th query image: 0
# Relevance of the 375-th map image for the 16-th query image: 0
# Relevance of the 376-th map image for the 16-th query image: 0
# Relevance of the 377-th map image for the 16-th query image: 0
# Relevance of the 378-th map image for the 16-th query image: 0
# Relevance of the 379-th map image for the 16-th query image: 0
# Relevance of the 380-th map image for the 16-th query image: 0
# Relevance of the 381-th map image for the 16-th query image: 0
# Relevance of the 382-th map image for the 16-th query image: 0
# Relevance of the 383-th map image for the 16-th query image: 0
# Relevance of the 384-th map image for the 16-th query image: 0
# Relevance of the 385-th map image for the 16-th query image: 0
# Relevance of the 386-th map image for the 16-th query image: 0
# Relevance of the 387-th map image for the 16-th query image: 0
# Relevance of the 388-th map image for the 16-th query image: 0
# Relevance of the 389-th map image for the 16-th query image: 0
# Relevance of the 390-th map image for the 16-th query image: 0
# Relevance of the 391-th map image for the 16-th query image: 0
# Relevance of the 392-th map image for the 16-th query image: 0
# Relevance of the 393-th map image for the 16-th query image: 0
# Relevance of the 394-th map image for the 16-th query image: 0
# Relevance of the 395-th map image for the 16-th query image: 0
# Relevance of the 396-th map image for the 16-th query image: 0
# Relevance of the 397-th map image for the 16-th query image: 0
# Relevance of the 398-th map image for the 16-th query image: 0
# Relevance of the 399-th map image for the 16-th query image: 0
# Relevance of the 400-th map image for the 16-th query image: 0
# Relevance of the 401-th map image for the 16-th query image: 0
# Relevance of the 402-th map image for the 16-th query image: 0
# Relevance of the 403-th map image for the 16-th query image: 0
# Relevance of the 404-th map image for the 16-th query image: 0
# Relevance of the 405-th map image for the 16-th query image: 0
# Relevance of the 406-th map image for the 16-th query image: 0
# Relevance of the 407-th map image for the 16-th query image: 0
# Relevance of the 408-th map image for the 16-th query image: 0
# Relevance of the 409-th map image for the 16-th query image: 0
# Relevance of the 410-th map image for the 16-th query image: 0
# Relevance of the 411-th map image for the 16-th query image: 0
# Relevance of the 412-th map image for the 16-th query image: 0
# Relevance of the 413-th map image for the 16-th query image: 0
# Relevance of the 414-th map image for the 16-th query image: 0
# Relevance of the 415-th map image for the 16-th query image: 0
# Relevance of the 416-th map image for the 16-th query image: 0
# Relevance of the 417-th map image for the 16-th query image: 0
# Relevance of the 418-th map image for the 16-th query image: 0
# Relevance of the 419-th map image for the 16-th query image: 0
# Relevance of the 420-th map image for the 16-th query image: 0
# Relevance of the 421-th map image for the 16-th query image: 0
# Relevance of the 422-th map image for the 16-th query image: 0
# Relevance of the 423-th map image for the 16-th query image: 0
# Relevance of the 424-th map image for the 16-th query image: 0
# Relevance of the 425-th map image for the 16-th query image: 0
# Relevance of the 426-th map image for the 16-th query image: 0
# Relevance of the 427-th map image for the 16-th query image: 0
# Relevance of the 428-th map image for the 16-th query image: 0
# Relevance of the 429-th map image for the 16-th query image: 0
# Relevance of the 430-th map image for the 16-th query image: 0
# Relevance of the 431-th map image for the 16-th query image: 0
# Relevance of the 432-th map image for the 16-th query image: 0
# Relevance of the 433-th map image for the 16-th query image: 0
# Relevance of the 434-th map image for the 16-th query image: 0
# Relevance of the 435-th map image for the 16-th query image: 0
# Relevance of the 436-th map image for the 16-th query image: 0
# Relevance of the 437-th map image for the 16-th query image: 0
# Relevance of the 438-th map image for the 16-th query image: 0
# Relevance of the 439-th map image for the 16-th query image: 0
# Relevance of the 440-th map image for the 16-th query image: 0
# Relevance of the 441-th map image for the 16-th query image: 0
# Relevance of the 442-th map image for the 16-th query image: 0
# Relevance of the 443-th map image for the 16-th query image: 0
# Relevance of the 444-th map image for the 16-th query image: 0
# Relevance of the 445-th map image for the 16-th query image: 0
# Relevance of the 446-th map image for the 16-th query image: 0
# Relevance of the 447-th map image for the 16-th query image: 0
# Relevance of the 448-th map image for the 16-th query image: 0
# Relevance of the 449-th map image for the 16-th query image: 0
# Relevance of the 450-th map image for the 16-th query image: 0
# Relevance of the 451-th map image for the 16-th query image: 0
# Relevance of the 452-th map image for the 16-th query image: 0
# Relevance of the 453-th map image for the 16-th query image: 0
# Relevance of the 454-th map image for the 16-th query image: 0
# Relevance of the 455-th map image for the 16-th query image: 0
# Relevance of the 456-th map image for the 16-th query image: 0
# Relevance of the 457-th map image for the 16-th query image: 0
# Relevance of the 458-th map image for the 16-th query image: 0
# Relevance of the 459-th map image for the 16-th query image: 0
# Relevance of the 460-th map image for the 16-th query image: 0
# Relevance of the 461-th map image for the 16-th query image: 0
# Relevance of the 462-th map image for the 16-th query image: 0
# Relevance of the 463-th map image for the 16-th query image: 0
# Relevance of the 464-th map image for the 16-th query image: 0
# Relevance of the 465-th map image for the 16-th query image: 0
# Relevance of the 466-th map image for the 16-th query image: 0
# Relevance of the 467-th map image for the 16-th query image: 0
# Relevance of the 468-th map image for the 16-th query image: 0
# Relevance of the 469-th map image for the 16-th query image: 0
# Relevance of the 470-th map image for the 16-th query image: 0
# Relevance of the 471-th map image for the 16-th query image: 0
# Relevance of the 472-th map image for the 16-th query image: 0
# Relevance of the 473-th map image for the 16-th query image: 0
# Relevance of the 474-th map image for the 16-th query image: 0
# Relevance of the 475-th map image for the 16-th query image: 0
# Relevance of the 476-th map image for the 16-th query image: 0
# Relevance of the 477-th map image for the 16-th query image: 0
# Relevance of the 478-th map image for the 16-th query image: 0
# Relevance of the 479-th map image for the 16-th query image: 0
# Relevance of the 480-th map image for the 16-th query image: 0
# Relevance of the 481-th map image for the 16-th query image: 0
# Relevance of the 482-th map image for the 16-th query image: 0
# Relevance of the 483-th map image for the 16-th query image: 0
# Relevance of the 484-th map image for the 16-th query image: 0
# Relevance of the 485-th map image for the 16-th query image: 0
# Relevance of the 486-th map image for the 16-th query image: 0
# Relevance of the 487-th map image for the 16-th query image: 0
# Relevance of the 488-th map image for the 16-th query image: 0
# Relevance of the 489-th map image for the 16-th query image: 0
# Relevance of the 490-th map image for the 16-th query image: 0
# Relevance of the 491-th map image for the 16-th query image: 0
# Relevance of the 492-th map image for the 16-th query image: 0
# Relevance of the 493-th map image for the 16-th query image: 0
# Relevance of the 494-th map image for the 16-th query image: 0
# Relevance of the 495-th map image for the 16-th query image: 0
# Relevance of the 496-th map image for the 16-th query image: 0
# Relevance of the 497-th map image for the 16-th query image: 0
# Relevance of the 498-th map image for the 16-th query image: 0
# Relevance of the 499-th map image for the 16-th query image: 0
# Relevance of the 500-th map image for the 16-th query image: 0
# Relevance of the 501-th map image for the 16-th query image: 0
# Relevance of the 502-th map image for the 16-th query image: 0
# Relevance of the 503-th map image for the 16-th query image: 0
# Relevance of the 504-th map image for the 16-th query image: 0
# Relevance of the 505-th map image for the 16-th query image: 0
# Relevance of the 506-th map image for the 16-th query image: 0
# Relevance of the 507-th map image for the 16-th query image: 0
# Relevance of the 508-th map image for the 16-th query image: 0
# Relevance of the 509-th map image for the 16-th query image: 0
# Relevance of the 510-th map image for the 16-th query image: 0
# Relevance of the 511-th map image for the 16-th query image: 0
# Relevance of the 512-th map image for the 16-th query image: 0
# Relevance of the 513-th map image for the 16-th query image: 0
# Relevance of the 514-th map image for the 16-th query image: 0
# Relevance of the 515-th map image for the 16-th query image: 0
# Relevance of the 516-th map image for the 16-th query image: 0
# Relevance of the 517-th map image for the 16-th query image: 0
# Relevance of the 518-th map image for the 16-th query image: 0
# Relevance of the 519-th map image for the 16-th query image: 0
# Relevance of the 520-th map image for the 16-th query image: 0
# Relevance of the 521-th map image for the 16-th query image: 0
# Relevance of the 522-th map image for the 16-th query image: 0
# Relevance of the 523-th map image for the 16-th query image: 0
# Relevance of the 524-th map image for the 16-th query image: 0
# Relevance of the 525-th map image for the 16-th query image: 0
# Relevance of the 526-th map image for the 16-th query image: 0
# Relevance of the 527-th map image for the 16-th query image: 0
# Relevance of the 528-th map image for the 16-th query image: 0
# Relevance of the 529-th map image for the 16-th query image: 0
# Relevance of the 530-th map image for the 16-th query image: 0
# Relevance of the 531-th map image for the 16-th query image: 0
# Relevance of the 532-th map image for the 16-th query image: 0
# Relevance of the 533-th map image for the 16-th query image: 0
# Relevance of the 534-th map image for the 16-th query image: 0
# Relevance of the 535-th map image for the 16-th query image: 0
# Relevance of the 536-th map image for the 16-th query image: 0
# Relevance of the 537-th map image for the 16-th query image: 0
# Relevance of the 538-th map image for the 16-th query image: 0
# Relevance of the 539-th map image for the 16-th query image: 0
# Relevance of the 540-th map image for the 16-th query image: 0
# Relevance of the 541-th map image for the 16-th query image: 0
# Relevance of the 542-th map image for the 16-th query image: 0
# Relevance of the 543-th map image for the 16-th query image: 0
# Relevance of the 544-th map image for the 16-th query image: 0
# Relevance of the 545-th map image for the 16-th query image: 0
# Relevance of the 546-th map image for the 16-th query image: 0
# Relevance of the 547-th map image for the 16-th query image: 0
# Relevance of the 548-th map image for the 16-th query image: 0
# Relevance of the 549-th map image for the 16-th query image: 0
# Relevance of the 550-th map image for the 16-th query image: 0
# Relevance of the 551-th map image for the 16-th query image: 0
# Relevance of the 552-th map image for the 16-th query image: 0
# Relevance of the 553-th map image for the 16-th query image: 0
# Relevance of the 554-th map image for the 16-th query image: 0
# Relevance of the 555-th map image for the 16-th query image: 0
# Relevance of the 556-th map image for the 16-th query image: 0
# Relevance of the 557-th map image for the 16-th query image: 0
# Relevance of the 558-th map image for the 16-th query image: 0
# Relevance of the 559-th map image for the 16-th query image: 0
# Relevance of the 560-th map image for the 16-th query image: 0
# Relevance of the 561-th map image for the 16-th query image: 0
# Relevance of the 562-th map image for the 16-th query image: 0
# Relevance of the 563-th map image for the 16-th query image: 0
# Relevance of the 564-th map image for the 16-th query image: 0
# Relevance of the 565-th map image for the 16-th query image: 0
# Relevance of the 566-th map image for the 16-th query image: 0
# Relevance of the 567-th map image for the 16-th query image: 0
# Relevance of the 568-th map image for the 16-th query image: 0
# Relevance of the 569-th map image for the 16-th query image: 0
# Relevance of the 570-th map image for the 16-th query image: 0
# Relevance of the 571-th map image for the 16-th query image: 0
# Relevance of the 572-th map image for the 16-th query image: 0
# Relevance of the 573-th map image for the 16-th query image: 0
# Relevance of the 574-th map image for the 16-th query image: 0
# Relevance of the 575-th map image for the 16-th query image: 0
# Relevance of the 576-th map image for the 16-th query image: 0
# Relevance of the 577-th map image for the 16-th query image: 0
# Relevance of the 578-th map image for the 16-th query image: 0
# Relevance of the 579-th map image for the 16-th query image: 0
# Relevance of the 580-th map image for the 16-th query image: 0
# Relevance of the 581-th map image for the 16-th query image: 0
# Relevance of the 582-th map image for the 16-th query image: 0
# Relevance of the 583-th map image for the 16-th query image: 0
# Relevance of the 584-th map image for the 16-th query image: 0
# Relevance of the 585-th map image for the 16-th query image: 0
# Relevance of the 586-th map image for the 16-th query image: 0
# Relevance of the 587-th map image for the 16-th query image: 0
# Relevance of the 588-th map image for the 16-th query image: 0
# Relevance of the 589-th map image for the 16-th query image: 0
# Relevance of the 590-th map image for the 16-th query image: 0
# Relevance of the 591-th map image for the 16-th query image: 0
# Relevance of the 592-th map image for the 16-th query image: 0
# Relevance of the 593-th map image for the 16-th query image: 0
# Relevance of the 594-th map image for the 16-th query image: 0
# Relevance of the 595-th map image for the 16-th query image: 0
# Relevance of the 596-th map image for the 16-th query image: 0
# Relevance of the 597-th map image for the 16-th query image: 0
# Relevance of the 598-th map image for the 16-th query image: 0
# Relevance of the 599-th map image for the 16-th query image: 0
# Relevance of the 600-th map image for the 16-th query image: 0
# Relevance of the 601-th map image for the 16-th query image: 0
# Relevance of the 602-th map image for the 16-th query image: 0
# Relevance of the 603-th map image for the 16-th query image: 0
# Relevance of the 604-th map image for the 16-th query image: 0
# Relevance of the 605-th map image for the 16-th query image: 0
# Relevance of the 606-th map image for the 16-th query image: 0
# Relevance of the 607-th map image for the 16-th query image: 0
# Relevance of the 608-th map image for the 16-th query image: 0
# Relevance of the 609-th map image for the 16-th query image: 0
# Relevance of the 610-th map image for the 16-th query image: 0
# Relevance of the 611-th map image for the 16-th query image: 0
# Relevance of the 612-th map image for the 16-th query image: 0
# Relevance of the 613-th map image for the 16-th query image: 0
# Relevance of the 614-th map image for the 16-th query image: 0
# Relevance of the 615-th map image for the 16-th query image: 0
# Relevance of the 616-th map image for the 16-th query image: 0
# Relevance of the 617-th map image for the 16-th query image: 0
# Relevance of the 618-th map image for the 16-th query image: 0
# Relevance of the 619-th map image for the 16-th query image: 0
# Relevance of the 620-th map image for the 16-th query image: 0
# Relevance of the 621-th map image for the 16-th query image: 0
# Relevance of the 622-th map image for the 16-th query image: 0
# Relevance of the 623-th map image for the 16-th query image: 0
# Relevance of the 624-th map image for the 16-th query image: 0
# Relevance of the 625-th map image for the 16-th query image: 0
# Relevance of the 626-th map image for the 16-th query image: 0
# Relevance of the 627-th map image for the 16-th query image: 0
# Relevance of the 628-th map image for the 16-th query image: 0
# Relevance of the 629-th map image for the 16-th query image: 0
# Relevance of the 630-th map image for the 16-th query image: 0
# Relevance of the 631-th map image for the 16-th query image: 0
# Relevance of the 632-th map image for the 16-th query image: 0
# Relevance of the 633-th map image for the 16-th query image: 0
# Relevance of the 634-th map image for the 16-th query image: 0
# Relevance of the 635-th map image for the 16-th query image: 0
# Relevance of the 636-th map image for the 16-th query image: 0
# Relevance of the 637-th map image for the 16-th query image: 0
# Relevance of the 638-th map image for the 16-th query image: 0
# Relevance of the 639-th map image for the 16-th query image: 0
# Relevance of the 640-th map image for the 16-th query image: 0
# Relevance of the 641-th map image for the 16-th query image: 0
# Relevance of the 642-th map image for the 16-th query image: 0
# Relevance of the 643-th map image for the 16-th query image: 0
# Relevance of the 644-th map image for the 16-th query image: 0
# Relevance of the 645-th map image for the 16-th query image: 0
# Relevance of the 646-th map image for the 16-th query image: 0
# Relevance of the 647-th map image for the 16-th query image: 0
# Relevance of the 648-th map image for the 16-th query image: 0
# Relevance of the 649-th map image for the 16-th query image: 0
# Relevance of the 650-th map image for the 16-th query image: 0
# Relevance of the 651-th map image for the 16-th query image: 0
# Relevance of the 652-th map image for the 16-th query image: 0
# Relevance of the 653-th map image for the 16-th query image: 0
# Relevance of the 654-th map image for the 16-th query image: 0
# Relevance of the 655-th map image for the 16-th query image: 0
# Relevance of the 656-th map image for the 16-th query image: 0
# Relevance of the 657-th map image for the 16-th query image: 0
# Relevance of the 658-th map image for the 16-th query image: 0
# Relevance of the 659-th map image for the 16-th query image: 0
# Relevance of the 660-th map image for the 16-th query image: 0
# Relevance of the 661-th map image for the 16-th query image: 0
# Relevance of the 662-th map image for the 16-th query image: 0
# Relevance of the 663-th map image for the 16-th query image: 0
# Relevance of the 664-th map image for the 16-th query image: 0
# Relevance of the 665-th map image for the 16-th query image: 0
# Relevance of the 666-th map image for the 16-th query image: 0
# Relevance of the 667-th map image for the 16-th query image: 0
# Relevance of the 668-th map image for the 16-th query image: 0
# Relevance of the 669-th map image for the 16-th query image: 0
# Relevance of the 670-th map image for the 16-th query image: 0
# Relevance of the 671-th map image for the 16-th query image: 0
# Relevance of the 672-th map image for the 16-th query image: 0
# Relevance of the 673-th map image for the 16-th query image: 0
# Relevance of the 674-th map image for the 16-th query image: 0
# Relevance of the 675-th map image for the 16-th query image: 0
# Relevance of the 676-th map image for the 16-th query image: 0
# Relevance of the 677-th map image for the 16-th query image: 0
# Relevance of the 678-th map image for the 16-th query image: 0
# Relevance of the 679-th map image for the 16-th query image: 0
# Relevance of the 680-th map image for the 16-th query image: 0
# Relevance of the 681-th map image for the 16-th query image: 0
# Relevance of the 682-th map image for the 16-th query image: 0
# Relevance of the 683-th map image for the 16-th query image: 0
# Relevance of the 684-th map image for the 16-th query image: 0
# Relevance of the 685-th map image for the 16-th query image: 0
# Relevance of the 686-th map image for the 16-th query image: 0
# Relevance of the 687-th map image for the 16-th query image: 0
# Relevance of the 688-th map image for the 16-th query image: 0
# Relevance of the 689-th map image for the 16-th query image: 0
# Relevance of the 690-th map image for the 16-th query image: 0
# Relevance of the 691-th map image for the 16-th query image: 0
# Relevance of the 692-th map image for the 16-th query image: 0
# Relevance of the 693-th map image for the 16-th query image: 0
# Relevance of the 694-th map image for the 16-th query image: 0
# Relevance of the 695-th map image for the 16-th query image: 0
# Relevance of the 696-th map image for the 16-th query image: 0
# Relevance of the 697-th map image for the 16-th query image: 0
# Relevance of the 698-th map image for the 16-th query image: 0
# Relevance of the 699-th map image for the 16-th query image: 0
# Relevance of the 700-th map image for the 16-th query image: 0
# Relevance of the 701-th map image for the 16-th query image: 0
# Relevance of the 702-th map image for the 16-th query image: 0
# Relevance of the 703-th map image for the 16-th query image: 0
# Relevance of the 704-th map image for the 16-th query image: 0
# Relevance of the 705-th map image for the 16-th query image: 0
# Relevance of the 706-th map image for the 16-th query image: 0
# Relevance of the 707-th map image for the 16-th query image: 0
# Relevance of the 708-th map image for the 16-th query image: 0
# Relevance of the 709-th map image for the 16-th query image: 0
# Relevance of the 710-th map image for the 16-th query image: 0
# Relevance of the 711-th map image for the 16-th query image: 0
# Relevance of the 712-th map image for the 16-th query image: 0
# Relevance of the 713-th map image for the 16-th query image: 0
# Relevance of the 714-th map image for the 16-th query image: 0
# Relevance of the 715-th map image for the 16-th query image: 0
# Relevance of the 716-th map image for the 16-th query image: 0
# Relevance of the 717-th map image for the 16-th query image: 0
# Relevance of the 718-th map image for the 16-th query image: 0
# Relevance of the 719-th map image for the 16-th query image: 0
# Relevance of the 720-th map image for the 16-th query image: 0
# Relevance of the 721-th map image for the 16-th query image: 0
# Relevance of the 722-th map image for the 16-th query image: 0
# Relevance of the 723-th map image for the 16-th query image: 0
# Relevance of the 724-th map image for the 16-th query image: 0
# Relevance of the 725-th map image for the 16-th query image: 0
# Relevance of the 726-th map image for the 16-th query image: 0
# Relevance of the 727-th map image for the 16-th query image: 0
# Relevance of the 728-th map image for the 16-th query image: 0
# Relevance of the 729-th map image for the 16-th query image: 0
# Relevance of the 730-th map image for the 16-th query image: 0
# Relevance of the 731-th map image for the 16-th query image: 0
# Relevance of the 732-th map image for the 16-th query image: 0
# Relevance of the 733-th map image for the 16-th query image: 0
# Relevance of the 734-th map image for the 16-th query image: 0
# Relevance of the 735-th map image for the 16-th query image: 0
# Relevance of the 736-th map image for the 16-th query image: 0
# Relevance of the 737-th map image for the 16-th query image: 0
# Relevance of the 738-th map image for the 16-th query image: 0
# Relevance of the 739-th map image for the 16-th query image: 0
# Relevance of the 740-th map image for the 16-th query image: 0
# Relevance of the 741-th map image for the 16-th query image: 0
# Relevance of the 742-th map image for the 16-th query image: 0
# Relevance of the 743-th map image for the 16-th query image: 0
# Relevance of the 744-th map image for the 16-th query image: 0
# Relevance of the 745-th map image for the 16-th query image: 0
# Relevance of the 746-th map image for the 16-th query image: 0
# Relevance of the 747-th map image for the 16-th query image: 0
# Relevance of the 748-th map image for the 16-th query image: 0
# Relevance of the 749-th map image for the 16-th query image: 0
# Relevance of the 750-th map image for the 16-th query image: 0
# Relevance of the 751-th map image for the 16-th query image: 0
# Relevance of the 752-th map image for the 16-th query image: 0
# Relevance of the 753-th map image for the 16-th query image: 0
# Relevance of the 754-th map image for the 16-th query image: 0
# Relevance of the 755-th map image for the 16-th query image: 0
# Relevance of the 756-th map image for the 16-th query image: 0
# Relevance of the 757-th map image for the 16-th query image: 0
# Relevance of the 758-th map image for the 16-th query image: 0
# Relevance of the 759-th map image for the 16-th query image: 0
# Relevance of the 760-th map image for the 16-th query image: 0
# Relevance of the 761-th map image for the 16-th query image: 0
# Relevance of the 762-th map image for the 16-th query image: 0
# Relevance of the 763-th map image for the 16-th query image: 0
# Relevance of the 764-th map image for the 16-th query image: 0
# Relevance of the 765-th map image for the 16-th query image: 0
# Relevance of the 766-th map image for the 16-th query image: 0
# Relevance of the 767-th map image for the 16-th query image: 0
# Relevance of the 768-th map image for the 16-th query image: 0
# Relevance of the 769-th map image for the 16-th query image: 0
# Relevance of the 770-th map image for the 16-th query image: 0
# Relevance of the 771-th map image for the 16-th query image: 0
# Relevance of the 772-th map image for the 16-th query image: 0
# Relevance of the 773-th map image for the 16-th query image: 0
# Relevance of the 774-th map image for the 16-th query image: 0
# Relevance of the 775-th map image for the 16-th query image: 0
# Relevance of the 776-th map image for the 16-th query image: 0
# Relevance of the 777-th map image for the 16-th query image: 0
# Relevance of the 778-th map image for the 16-th query image: 0
# Relevance of the 779-th map image for the 16-th query image: 0
# Relevance of the 780-th map image for the 16-th query image: 0
# Relevance of the 781-th map image for the 16-th query image: 0
# Relevance of the 782-th map image for the 16-th query image: 0
# Relevance of the 783-th map image for the 16-th query image: 0
# Relevance of the 784-th map image for the 16-th query image: 0
# Relevance of the 785-th map image for the 16-th query image: 0
# Relevance of the 786-th map image for the 16-th query image: 0
# Relevance of the 787-th map image for the 16-th query image: 0
# Relevance of the 788-th map image for the 16-th query image: 0
# Relevance of the 789-th map image for the 16-th query image: 0
# Relevance of the 790-th map image for the 16-th query image: 0
# Relevance of the 791-th map image for the 16-th query image: 0
# Relevance of the 792-th map image for the 16-th query image: 0
# Relevance of the 793-th map image for the 16-th query image: 0
# Relevance of the 794-th map image for the 16-th query image: 0
# Relevance of the 795-th map image for the 16-th query image: 0
# Relevance of the 796-th map image for the 16-th query image: 0
# Relevance of the 797-th map image for the 16-th query image: 0
# Relevance of the 798-th map image for the 16-th query image: 0
# Relevance of the 799-th map image for the 16-th query image: 0
# Relevance of the 800-th map image for the 16-th query image: 0
# Relevance of the 801-th map image for the 16-th query image: 0
# Relevance of the 802-th map image for the 16-th query image: 0
# Relevance of the 803-th map image for the 16-th query image: 0
# Relevance of the 804-th map image for the 16-th query image: 0
# Relevance of the 805-th map image for the 16-th query image: 0
# Relevance of the 806-th map image for the 16-th query image: 0
# Relevance of the 807-th map image for the 16-th query image: 0
# Relevance of the 808-th map image for the 16-th query image: 0
# Relevance of the 809-th map image for the 16-th query image: 0
# Relevance of the 810-th map image for the 16-th query image: 0
# Relevance of the 811-th map image for the 16-th query image: 0
# Relevance of the 812-th map image for the 16-th query image: 0
# Relevance of the 813-th map image for the 16-th query image: 0
# Relevance of the 814-th map image for the 16-th query image: 0
# Relevance of the 815-th map image for the 16-th query image: 0
# Relevance of the 816-th map image for the 16-th query image: 0
# Relevance of the 817-th map image for the 16-th query image: 0
# Relevance of the 818-th map image for the 16-th query image: 0
# Relevance of the 819-th map image for the 16-th query image: 0
# Relevance of the 820-th map image for the 16-th query image: 0
# Relevance of the 821-th map image for the 16-th query image: 0
# Relevance of the 822-th map image for the 16-th query image: 0
# Relevance of the 823-th map image for the 16-th query image: 0
# Relevance of the 824-th map image for the 16-th query image: 0
# Relevance of the 825-th map image for the 16-th query image: 0
# Relevance of the 826-th map image for the 16-th query image: 0
# Relevance of the 827-th map image for the 16-th query image: 0
# Relevance of the 828-th map image for the 16-th query image: 0
# Relevance of the 829-th map image for the 16-th query image: 0
# Relevance of the 830-th map image for the 16-th query image: 0
# Relevance of the 831-th map image for the 16-th query image: 0
# Relevance of the 832-th map image for the 16-th query image: 0
# Relevance of the 833-th map image for the 16-th query image: 0
# Relevance of the 834-th map image for the 16-th query image: 0
# Relevance of the 835-th map image for the 16-th query image: 0
# Relevance of the 836-th map image for the 16-th query image: 0
# Relevance of the 837-th map image for the 16-th query image: 0
# Relevance of the 838-th map image for the 16-th query image: 0
# Relevance of the 839-th map image for the 16-th query image: 0
# Relevance of the 840-th map image for the 16-th query image: 0
# Relevance of the 841-th map image for the 16-th query image: 0
# Relevance of the 842-th map image for the 16-th query image: 0
# Relevance of the 843-th map image for the 16-th query image: 0
# Relevance of the 844-th map image for the 16-th query image: 0
# Relevance of the 845-th map image for the 16-th query image: 0
# Relevance of the 846-th map image for the 16-th query image: 0
# Relevance of the 847-th map image for the 16-th query image: 0
# Relevance of the 848-th map image for the 16-th query image: 0
# Relevance of the 849-th map image for the 16-th query image: 0
# Relevance of the 850-th map image for the 16-th query image: 0
# Relevance of the 851-th map image for the 16-th query image: 0
# Relevance of the 852-th map image for the 16-th query image: 0
# Relevance of the 853-th map image for the 16-th query image: 0
# Relevance of the 854-th map image for the 16-th query image: 0
# Relevance of the 855-th map image for the 16-th query image: 0
# Relevance of the 856-th map image for the 16-th query image: 0
# Relevance of the 857-th map image for the 16-th query image: 0
# Relevance of the 858-th map image for the 16-th query image: 0
# Relevance of the 859-th map image for the 16-th query image: 0
# Relevance of the 860-th map image for the 16-th query image: 0
# Relevance of the 861-th map image for the 16-th query image: 0
# Relevance of the 862-th map image for the 16-th query image: 0
# Relevance of the 863-th map image for the 16-th query image: 0
# Relevance of the 864-th map image for the 16-th query image: 0
# Relevance of the 865-th map image for the 16-th query image: 0
# Relevance of the 866-th map image for the 16-th query image: 0
# Relevance of the 867-th map image for the 16-th query image: 0
# Relevance of the 868-th map image for the 16-th query image: 0
# Relevance of the 869-th map image for the 16-th query image: 0
# Relevance of the 870-th map image for the 16-th query image: 0
# Relevance of the 871-th map image for the 16-th query image: 0
# Relevance of the 872-th map image for the 16-th query image: 0
# Relevance of the 873-th map image for the 16-th query image: 0
# Relevance of the 874-th map image for the 16-th query image: 0
# Relevance of the 875-th map image for the 16-th query image: 0
# Relevance of the 876-th map image for the 16-th query image: 0
# Relevance of the 877-th map image for the 16-th query image: 0
# Relevance of the 878-th map image for the 16-th query image: 0
# Relevance of the 879-th map image for the 16-th query image: 0
# Relevance of the 880-th map image for the 16-th query image: 0
# Relevance of the 881-th map image for the 16-th query image: 0
# Relevance of the 882-th map image for the 16-th query image: 0
# Relevance of the 883-th map image for the 16-th query image: 0
# Relevance of the 884-th map image for the 16-th query image: 0
# Relevance of the 885-th map image for the 16-th query image: 0
# Relevance of the 886-th map image for the 16-th query image: 0
# Relevance of the 887-th map image for the 16-th query image: 0
# Relevance of the 888-th map image for the 16-th query image: 0
# Relevance of the 889-th map image for the 16-th query image: 0
# Relevance of the 890-th map image for the 16-th query image: 0
# Relevance of the 891-th map image for the 16-th query image: 0
# Relevance of the 892-th map image for the 16-th query image: 0
# Relevance of the 893-th map image for the 16-th query image: 0
# Relevance of the 894-th map image for the 16-th query image: 0
# Relevance of the 895-th map image for the 16-th query image: 0
# Relevance of the 896-th map image for the 16-th query image: 0
# Relevance of the 897-th map image for the 16-th query image: 0
# Relevance of the 898-th map image for the 16-th query image: 0
# Relevance of the 899-th map image for the 16-th query image: 0
# Relevance of the 900-th map image for the 16-th query image: 0
# Relevance of the 901-th map image for the 16-th query image: 0
# Relevance of the 902-th map image for the 16-th query image: 0
# Relevance of the 903-th map image for the 16-th query image: 0
# Relevance of the 904-th map image for the 16-th query image: 0
# Relevance of the 905-th map image for the 16-th query image: 0
# Relevance of the 906-th map image for the 16-th query image: 0
# Relevance of the 907-th map image for the 16-th query image: 0
# Relevance of the 908-th map image for the 16-th query image: 0
# Relevance of the 909-th map image for the 16-th query image: 0
# Relevance of the 910-th map image for the 16-th query image: 0
# Relevance of the 911-th map image for the 16-th query image: 0
# Relevance of the 912-th map image for the 16-th query image: 0
# Relevance of the 913-th map image for the 16-th query image: 0
# Relevance of the 914-th map image for the 16-th query image: 0
# Relevance of the 915-th map image for the 16-th query image: 0
# Relevance of the 916-th map image for the 16-th query image: 0
# Relevance of the 917-th map image for the 16-th query image: 0
# Relevance of the 918-th map image for the 16-th query image: 0
# Relevance of the 919-th map image for the 16-th query image: 0
# Relevance of the 920-th map image for the 16-th query image: 0
# Relevance of the 921-th map image for the 16-th query image: 0
# Relevance of the 922-th map image for the 16-th query image: 0
# Relevance of the 923-th map image for the 16-th query image: 0
# Relevance of the 924-th map image for the 16-th query image: 0
# Relevance of the 925-th map image for the 16-th query image: 0
# Relevance of the 926-th map image for the 16-th query image: 0
# Relevance of the 927-th map image for the 16-th query image: 0
# Relevance of the 928-th map image for the 16-th query image: 0
# Relevance of the 929-th map image for the 16-th query image: 0
# Relevance of the 930-th map image for the 16-th query image: 0
# Relevance of the 931-th map image for the 16-th query image: 0
# Relevance of the 932-th map image for the 16-th query image: 0
# Relevance of the 933-th map image for the 16-th query image: 0
# Relevance of the 934-th map image for the 16-th query image: 0
# Relevance of the 935-th map image for the 16-th query image: 0
# Relevance of the 936-th map image for the 16-th query image: 0
# Relevance of the 937-th map image for the 16-th query image: 0
# Relevance of the 938-th map image for the 16-th query image: 0
# Relevance of the 939-th map image for the 16-th query image: 0
# Relevance of the 940-th map image for the 16-th query image: 0
# Relevance of the 941-th map image for the 16-th query image: 0
# Relevance of the 942-th map image for the 16-th query image: 0
# Relevance of the 943-th map image for the 16-th query image: 0
# Relevance of the 944-th map image for the 16-th query image: 0
# Relevance of the 945-th map image for the 16-th query image: 0
# Relevance of the 946-th map image for the 16-th query image: 0
# Relevance of the 947-th map image for the 16-th query image: 0
# Relevance of the 948-th map image for the 16-th query image: 0
# Relevance of the 949-th map image for the 16-th query image: 0
# Relevance of the 950-th map image for the 16-th query image: 0
# Relevance of the 951-th map image for the 16-th query image: 0
# Relevance of the 952-th map image for the 16-th query image: 0
# Relevance of the 953-th map image for the 16-th query image: 0
# Relevance of the 954-th map image for the 16-th query image: 0
# Relevance of the 955-th map image for the 16-th query image: 0
# Relevance of the 956-th map image for the 16-th query image: 0
# Relevance of the 957-th map image for the 16-th query image: 0
# Relevance of the 958-th map image for the 16-th query image: 0
# Relevance of the 959-th map image for the 16-th query image: 0
# Relevance of the 960-th map image for the 16-th query image: 0
# Relevance of the 961-th map image for the 16-th query image: 0
# Relevance of the 962-th map image for the 16-th query image: 0
# Relevance of the 963-th map image for the 16-th query image: 0
# Relevance of the 964-th map image for the 16-th query image: 0
# Relevance of the 965-th map image for the 16-th query image: 0
# Relevance of the 966-th map image for the 16-th query image: 0
# Relevance of the 967-th map image for the 16-th query image: 0
# Relevance of the 968-th map image for the 16-th query image: 0
# Relevance of the 969-th map image for the 16-th query image: 0
# Relevance of the 970-th map image for the 16-th query image: 0
# Relevance of the 971-th map image for the 16-th query image: 0
# Relevance of the 972-th map image for the 16-th query image: 0
# Relevance of the 973-th map image for the 16-th query image: 0
# Relevance of the 974-th map image for the 16-th query image: 0
# Relevance of the 975-th map image for the 16-th query image: 0
# Relevance of the 976-th map image for the 16-th query image: 0
# Relevance of the 977-th map image for the 16-th query image: 0
# Relevance of the 978-th map image for the 16-th query image: 0
# Relevance of the 979-th map image for the 16-th query image: 0
# Relevance of the 980-th map image for the 16-th query image: 0
# Relevance of the 981-th map image for the 16-th query image: 0
# Relevance of the 982-th map image for the 16-th query image: 0
# Relevance of the 983-th map image for the 16-th query image: 0
# Relevance of the 984-th map image for the 16-th query image: 0
# Relevance of the 985-th map image for the 16-th query image: 0
# Relevance of the 986-th map image for the 16-th query image: 0
# Relevance of the 987-th map image for the 16-th query image: 0
# Relevance of the 988-th map image for the 16-th query image: 0
# Relevance of the 989-th map image for the 16-th query image: 0
# Relevance of the 990-th map image for the 16-th query image: 0
# Relevance of the 991-th map image for the 16-th query image: 0
# Relevance of the 992-th map image for the 16-th query image: 0
# Relevance of the 993-th map image for the 16-th query image: 0
# Relevance of the 994-th map image for the 16-th query image: 0
# Relevance of the 995-th map image for the 16-th query image: 0
# Relevance of the 996-th map image for the 16-th query image: 0
# Relevance of the 997-th map image for the 16-th query image: 0
# Relevance of the 998-th map image for the 16-th query image: 0
# Relevance of the 999-th map image for the 16-th query image: 0

# %% [markdown]
# # Bag of Words representation
# As seen in the lecture, in order to construct a dictionary of 'visual' terms (words) from a collection of images, one can extract local features from the images (e.g. keypoints) and use a clustering algorithm to automatically find groups (i.e. clusters) of similar local features. The centroid of a cluster is also a feature vector and can be considered as a term to be used for the search and retrieval of similar images.
#
# In this assignment, we use the [$K$-Means clustering algorithm](https://www.youtube.com/watch?v=_aWzGGNrcic) (where $k$ is defined as a parameter by us) to extract the visual dictionary of terms from the images in the map collection (in the cells below you will find more information).
#
#
# In the following code (please study it), we:
# * load the list of images in the map collection
# * for each image we extract a maximum of 50 ORB keypoints (local keypoint features). Each keypoint is described by a vector of 256 elements (keypoint descriptor) that describes the local characteristics of the image.
# * use the set of keypoint descriptors (50 keypoints * 1000 images = 50000 vectors) as input of the k-Means clustering algorithm
# * compute k=32 cluster centroids (which correspond to the 32 terms of our dictionary) - k is a configurable parameter
#
# > __Note:__ Please, find more information about ORB in the [ORB paper](https://ieeexplore.ieee.org/document/6126544) and in the [Scikit Image ORB documentation](https://scikit-image.org/docs/dev/auto_examples/features_detection/plot_orb.html).
#
# > __Note 2:__ it may take some time to extract the descriptors from all images. Once extracted you can save them, and reload them when needed. If you change the number of centroids k, then you need to recompute the cluster centers.

# %%
import os
import pickle
from skimage.feature import ORB, CENSURE, SIFT, BRIEF
from skimage.color import rgb2gray
from sklearn.cluster import KMeans
from skfda.ml.clustering import FuzzyCMeans, AgglomerativeClustering
from skfda import FDataGrid

# %%
# Initialize the ORB descriptor
# descriptor_extractor = ORB(n_keypoints=50)
descriptor_extractor = CENSURE()
brief = BRIEF()
# descriptor_extractor = SIFT()

# %%
# Initialize the KMeans clusterer
K = 32  # number of clusters (equivalent to the number of words) we want to estimate
num_initialization = 5 # Number of time the k-means algorithm will be run with different centroid seeds.
clusterer = KMeans(n_clusters=K, n_init=num_initialization)
#clusterer = AgglomerativeClustering(n_clusters=K)
#clusterer = FuzzyCMeans(n_clusters=K, n_init=num_initialization)

# %%
# Define the filenames for saving the computed descriptors, centroids and BoW vectors
filename_descriptors_map = f'data02/{descriptor_extractor.__class__.__name__}-descriptors_map.bin'
filename_centroids = f'data02/{descriptor_extractor.__class__.__name__}-{clusterer.__class__.__name__}-{K}-centroids.bin'
filename_bow_map = f'data02/{descriptor_extractor.__class__.__name__}-{clusterer.__class__.__name__}-{K}-bow_map_images.bin'
filename_evaluation = f'data02/evaluation-{descriptor_extractor.__class__.__name__}-{clusterer.__class__.__name__}-{K}.txt'
print(filename_descriptors_map, filename_centroids, filename_bow_map)
# Out:
# data02/CENSURE-descriptors_map.bin data02/CENSURE-KMeans-32-centroids.bin data02/CENSURE-KMeans-32-bow_map_images.bin

# %%
# check if descriptors are already computed
if os.path.isfile(filename_descriptors_map):
    print('Loading descriptors')
    # load pre-computed descriptors
    f = open(filename_descriptors_map, 'rb')
    descriptors = pickle.load(f)
    f.close()
else:
    print('Computing descriptors')
    
    # Initialize the data structure that will contain all the descriptors
    descriptors = None
    # Loop over map images
    for img_name in m_imgs:
        #img = Image.open(os.path.join('data_image_retrieval/', img_name)).convert()
        #img = np.asarray(img)
        img = plt.imread(os.path.join('data02/', img_name))
        img = rgb2gray(img)
        
        # Extract ORB descriptors
        if descriptor_extractor.__class__.__name__ == 'ORB' or descriptor_extractor.__class__.__name__ == 'SIFT':
            descriptor_extractor.detect_and_extract(img)
            descriptors_img = descriptor_extractor.descriptors  # descriptors (the feature vectors)
        elif descriptor_extractor.__class__.__name__ == 'CENSURE':
            descriptor_extractor.detect(img)
            brief.extract(img, descriptor_extractor.keypoints)
            descriptors_img = brief.descriptors  # descriptors (the feature vectors)
        # keypoints1 = descriptor_extractor.keypoints  # position of the points (not interesting for us)
        
        
        # Accumulate the computed descriptors
        if descriptors is None:
            descriptors = descriptors_img
        else:
            descriptors = np.vstack( (descriptors, descriptors_img))
        #print(descriptors.shape)
    
    # save descriptors (uncomment if you want to save the computed descriptors)
    f = open(filename_descriptors_map, 'wb')
    pickle.dump(descriptors, f)
    f.close()
    
# We have extracted 50 descriptors per image, for 1000 images. The ORB descriptors have length 256
print(descriptors.shape)
# Out:
# Computing descriptors
# (50012, 256)

# %% [markdown]
# ## Clustering
# Following the Bag of Words framework (see the slides of the lecture), we can define the basic 'words' that compose the images via a clustering algorithm that takes the descriptors of the map images (training) as input. The basic 'words' form a so called visual vocabulary and are learned by grouping together those descriptor vectors that are most similar, i.e. their distance is lower than that between other descriptors.
#
# We do it by using the $K$-Means algorithm: find [here](https://en.wikipedia.org/wiki/K-means_clustering) some more information about KMeans and [here](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html) the reference documentation of the algorithm in Scikit-learn. Also an explanatory video with examples [here](https://www.youtube.com/watch?v=_aWzGGNrcic).
#
# > Note: running the clustering may take few minutes. Once computed, you can save the centroids and subsequently load tham before use. If you change the value of K, you need to recompute the clusters.

# %%
# check if centroids are already computed
if os.path.isfile(filename_centroids):
    print('Loading centroids')
    # load pre-computed descriptors
    f = open(filename_centroids, 'rb')
    centroids = pickle.load(f)
    f.close()
else:
    print('Computing centroids')
    # Compute the centroids of the clusters
    if clusterer.__class__.__name__ == 'KMeans':
        clusters = clusterer.fit(descriptors)  # we use the descriptors extracted from the map (training) images before
        centroids = clusters.cluster_centers_
    else:
        fd = FDataGrid(descriptors.astype(np.float64))
        clusters = clusterer.fit(fd)  # we use the descriptors extracted from the map (training) images before
        centroids = np.squeeze(clusters.cluster_centers_.data_matrix)
    
    # save centroids
    f = open(filename_centroids, 'wb')
    pickle.dump(centroids, f)
    f.close()
    
    # Delete the bow_map_images.bin file if you change the number of centroids
    if os.path.isfile(filename_bow_map):
        os.remove(filename_bow_map)

print("Shape of the centroids matrix: ", centroids.shape)
print("We computed ", centroids.shape[0], "centroids of length ", centroids.shape[1], " (the same of the descriptor)")
# Remember: the centroids can be considered as the words that compose our documents 
# -> in this case the basic components of the images
# Out:
# Computing centroids
# Shape of the centroids matrix:  (32, 256)
# We computed  32 centroids of length  256  (the same of the descriptor)

# %% [markdown]
# ## _'Bag of words' vector computation_
#
# In order to compute the BoW representation of an image, we have to count the occurrences of the visual 'words', i.e. the local features, that we have learned in our visual vocabulary (using the $K$-Means clustering).
#
# Given an image, we do the following:
#    * we extract the local descriptors (we are using ORB descriptors in this assignment)
#    * for each descriptor we find the closest 'word' (i.e. the closes cluster centroid) in the visual vocabulary
#    * we sum +1 to the counting of the occurence of the 'word' (in this way we construct the histogram of the occurrence of the visual 'words')
#
# An image is thus described with a vector (of $K$ elements) that is an histogram of the occurrence of the words in the learned visual vocabulary (similar to the occurrence of words in a text document).
#
# In the following, implement the core of the function that computes the BoW vector. The function takes as input the centroids of the learned clusters (i.e. the vocabulary of the visual words) and the set of descriptors extracted from an image. It must return the BoW vector.

# %%
from tqdm import tqdm
import os
from skimage.color import rgb2gray


# compute the bag of word vector for an image
def bag_of_words(centroids, img_descriptors):
    n_centroids = centroids.shape[0]  # number of centroids found with the KMeans clustering
    n_descriptors = img_descriptors.shape[0]  # number of descriptors extracted from the image
    
    # initialization of the bag of words (BoW) vector
    # Note that the BoW vector has length equal to the number of cluster centroids
    # The cluster centroids are indeed our visual words, and the BoW will be the histogram of these words found in the given image
    bow_vector = np.zeros(n_centroids)  
    
    for i in range(n_descriptors):
        ## BEGIN ANSWER
        distances = np.linalg.norm(centroids - img_descriptors[i], axis=1)
        closest_centroid_idx = np.argmin(distances)
        bow_vector[closest_centroid_idx] += 1
        ## END ANSWER
    return bow_vector

# %% [markdown]
# ### Bag of words representation of the map images
# Given a query image, our aim is to find similar images in our collection (i.e. map) images.
# To do that, we have to convert the query image into its Bag of words (BoW) representation and look for similar vectors in the collection (i.e. map) images.
#
# At this stage, since we will do many queries, it is handy to compute the BoW vectors for all images in the collection (i.e. map) and reuse them for multiple queries. (We convert all images in the collection to their BoW representation).
#
# > It is advised to study and understand the code below (it may take some time to run).

# %%
from sklearn import preprocessing
# check if descriptors are already computed
if os.path.isfile(filename_bow_map):
    print('Loading BoW vectors')
    # load pre-computed descriptors
    f = open(filename_bow_map, 'rb')
    bow_map_images = pickle.load(f)
    f.close()
else:
    print('Computing BoW vectors')
    bow_map_images = None
    # loop over the images in the map set
    for img_name in tqdm(m_imgs):
        # load image
        img = plt.imread(os.path.join('data02/', img_name))
        img = rgb2gray(img)
        
        # extract the keypoints and corresponding descriptors (50 ORB descriptors)
        if descriptor_extractor.__class__.__name__ == 'ORB' or descriptor_extractor.__class__.__name__ == 'SIFT':
            descriptor_extractor.detect_and_extract(img)
            img_descriptors = descriptor_extractor.descriptors  # descriptors (the feature vectors)
        elif descriptor_extractor.__class__.__name__ == 'CENSURE':
            descriptor_extractor.detect(img)
            brief.extract(img, descriptor_extractor.keypoints)
            img_descriptors = brief.descriptors  # descriptors (the feature vectors)
        
        # compute BoW representation of the image (using the basic 'words', i.e. centroids, computed earlier)
        bow = bag_of_words(centroids, img_descriptors)
        # add the computed BoW vector to the set of map representations
        if bow_map_images is None:
            bow_map_images = bow
        else:
            bow_map_images = np.vstack( (bow_map_images, bow))
    # Compute z-score statistics
    scaler = preprocessing.StandardScaler().fit(bow_map_images)
    # Normalize the vectors of the map collection (0 mean and 1 std)
    bow_map_images = scaler.transform(bow_map_images)
    # Save the BoW vectors (uncomment if you want to save the computed descriptors)
    f = open(filename_bow_map, 'wb')
    pickle.dump(bow_map_images, f)
    f.close()
print(bow_map_images.shape)
# Out:
# Computing BoW vectors
# 100%|██████████| 1000/1000 [01:12<00:00, 13.71it/s]
# (1000, 32)

# %% [markdown]
# At this point, the 1000 images in the map have been converted into their BoW representation. The data structure has size $NxK$, where $N=1000$ is the number of map images, while $K=32$ is the number of basic 'words' of the BoW representation.

# %% [markdown]
# ## _Retrieve images_
# We are ready to retrieve images from the collection (i.e. map) images, given the BoW representation of a query image. In order to do that, compute the Euclidean distance between the BoW vector of the query image and the BoW vector of all the collection images and return those with the smaller distance.
#
# _Hint:_ after computing the distances between the query image BoW vector and all BoW vectors of the map image, you may want to sort them in ascending order; the Numpy function [argsort](https://numpy.org/doc/stable/reference/generated/numpy.argsort.html) may turn out to be useful.
#
# > For this exercise you are asked to compute the Euclidean distance, but other distance metrics can also be used, e.g. Cosine distance, Minkowski Distance, Manhattan distance, etc. (this is left to you, if you want to explore them as well)

# %%
def distance_euclidean(map_bow_vectors, query_bow):
    return np.linalg.norm(map_bow_vectors - query_bow, axis=1)

def distance_manhattan(map_bow_vectors, query_bow):
    return np.sum(map_bow_vectors - query_bow, axis=1)

def distance_chebychev(map_bow_vectors, query_bow):
    return np.max(map_bow_vectors - query_bow, axis=1)

def distance_cosine(map_bow_vectors, query_bow):
    return np.dot(map_bow_vectors,query_bow)

# %%
def precision_at_k(relevant, retrieved, k):
    top_k_retrieved = retrieved[:k]
    if len(top_k_retrieved) == 0:
        return 0
    relevant_and_top_k = set(relevant).intersection(set(top_k_retrieved))
    return len(relevant_and_top_k) / k

def average_precision(relevant, retrieved):
    intersect_size = 0.0
    precision_sum = 0.0
    for i, r in enumerate(retrieved):
        if r in relevant:
            intersect_size += 1
            precision_sum += intersect_size / (i + 1)
    if intersect_size == 0:
        return 0
    return precision_sum / intersect_size

def mean_average_precision(all_relevant, all_retrieved):
    total = 0
    for relevant, retrieved in zip(all_relevant, all_retrieved):
        total += average_precision(relevant, retrieved)
    return total / len(all_relevant)

# %%
def retrieve_images(query_idx, distance = distance_euclidean):
    """
    Retrieve the most similar images to the query image with index query_idx
    :param query_idx: index of the query image
    :param distance: distance function to use
    :return: an array of indices of the most similar images
    """
    bow_distances = distance(bow_map_images, bow_map_images[query_idx,:])
    retrieved_images = np.argsort(bow_distances)
    return retrieved_images

# %%
def evaluate(distance = distance_euclidean):
    """
    Compute the Mean Average Precision (MAP) for the given distance function
    :param distance: 
    :return: 
    """
    print(f"{descriptor_extractor.__class__.__name__} {clusterer.__class__.__name__} {K} {distance.__name__}")
    # # Retrieve the most similar images to query image 221 (index 221-1=220)
    # query_idx = 220
    # # Retrieve the indices of the top-10 similar images from the map
    # retrieved_images = retrieve_images(query_idx, distance = distance)
    # print('Indices of similar images retrieved: ', retrieved_images[:10])
    # # Indices of the relevant map images for the query: we have the relevance judgements (Ground truth)
    # relevant_images = np.where(sim[query_idx, :] == 1)[0]
    # print('Indices of relevant images (given in the GT relevance judgements): ', relevant_images)
    # print('P@5: ', precision_at_k(relevant_images, retrieved_images, k=5))
    # print('P@10: ', precision_at_k(relevant_images, retrieved_images, k=10))
    # For all query images
    all_relevant = []
    all_retrieved = []
    for query_idx in range(len(q_imgs)):
        retrieved_images = retrieve_images(query_idx, distance = distance)
        relevant_images = np.where(sim[query_idx, :] == 1)[0]
        all_relevant.append(relevant_images)
        all_retrieved.append(retrieved_images)
    mapr = mean_average_precision(all_relevant, all_retrieved)
    print('Mean Average Precision (MAP): %1.3f\n' % mapr)
    # append the results to the evaluation file
    f = open(filename_evaluation, 'a')
    write_str = f"{descriptor_extractor.__class__.__name__} {clusterer.__class__.__name__} {K} {distance.__name__} {mapr}\n"
    f.write(write_str)
    f.close()


evaluate(distance = distance_manhattan)
evaluate(distance = distance_chebychev)
evaluate(distance = distance_cosine)
evaluate(distance = distance_euclidean)
# Out:
# CENSURE KMeans 32 distance_manhattan
# Mean Average Precision (MAP): 0.014
#
# CENSURE KMeans 32 distance_chebychev
# Mean Average Precision (MAP): 0.021
#
# CENSURE KMeans 32 distance_cosine
# Mean Average Precision (MAP): 0.012
#
# CENSURE KMeans 32 distance_euclidean
# Mean Average Precision (MAP): 0.055
